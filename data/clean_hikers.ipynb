# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
path = "./downloads/"
garbage = pd.read_csv(os.path.join(path,'garbage.csv'))
visitors = pd.read_csv(os.path.join(path,'./visitor.csv'))

# %%
display(garbage)
display(visitors)
# Out:
#                                                    No   사무소명   2012년   2013년  \
# 0                                                  No   사무소명  쓰레기처리량  쓰레기처리량
# 1                                                  No   사무소명       톤       톤
# 2                                                  No   사무소명     원자료     원자료
# 3                                                   1     합계   1,653   1,494
# 4                                                   2    지리산      50      44
# 5                                                   3  지리산북부      87      79
# 6                                                   4  지리산남부      41      36
# 7                                                   5     경주      23      20
# 8                                                   6    계룡산      45      39
# 9                                                   7   한려해상      25      15
# 10                                                  8   한려동부      82      90
# ...

# %% [markdown]
# 데이버분석 시각화

# %%
garbage_df = garbage[3:-1] # 불필요한 행 삭제
garbage_df
# Out:
#     No   사무소명  2012년  2013년  2014년     2015년  2016년  2017년  2018년  2019년  \
# 3    1     합계  1,653  1,494  1,375  1,297.81  1,208  1,187  1,143  1,124
# 4    2    지리산     50     44     27        39     28     26     25     21
# 5    3  지리산북부     87     79     75        90     73     59     60     58
# 6    4  지리산남부     41     36     33        29     22     21     21     20
# 7    5     경주     23     20     13         9      6      5      5      5
# 8    6    계룡산     45     39     52        54     49     47     46     46
# 9    7   한려해상     25     15     15        18     86     82     80     78
# 10   8   한려동부     82     90     95       101     81     79     77     81
# 11   9    설악산    123    101     92        82     59     56     57     51
# 12  10    속리산    105     49     35        33     35     32     30     29
# 13  11    한라산    133    147     88     33.81     38     53     34     41
# 14  12    내장산     46     39     40        29     29     27     26     25
# ...

# %% [markdown]
# DataFrame의 인덱스를 보려면 .index 속성을, 컬럼을 보려면 .columns 속성을, 안에 들어있는 numpy 데이터를 보려면 .values 속성을 통해 확인하면 됩니다.

# %%
visitor_df = visitors[3:-1] # 불필요한 행 삭제
visitor_df.columns  #column만 출력
# Out:
# Index(['No', '분류', '2012년', '2013년', '2014년', '2015년', '2016년', '2017년',
#        '2018년', '2019년', '2020년', '2021년'],
#       dtype='object')
